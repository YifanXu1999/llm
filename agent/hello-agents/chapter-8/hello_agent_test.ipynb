# %%
# 配置好同级文件夹下.env中的大模型API
from hello_agents import SimpleAgent, HelloAgentsLLM, ToolRegistry
from hello_agents.tools import MemoryTool, RAGTool
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["LLM_API_KEY"] =  os.getenv("LLM_API_KEY")
os.environ["LLM_BASE_URL"] =  os.getenv("LLM_BASE_URL")
os.environ["LLM_MODEL_ID"] =  os.getenv("LLM_MODEL_ID")
# 创建LLM实例
llm = HelloAgentsLLM(provider='deepseek', model=os.getenv("LLM_MODEL_ID"), api_key=os.getenv("LLM_API_KEY"), base_url=os.getenv("LLM_BASE_URL"))

# 创建Agent
agent = SimpleAgent(
    name="智能助手",
    llm=llm,
    system_prompt="你是一个有记忆和知识检索能力的AI助手"
)

# 创建工具注册表
tool_registry = ToolRegistry()

# 添加记忆工具
memory_tool = MemoryTool(user_id="user123")
tool_registry.register_tool(memory_tool)

# 添加RAG工具
rag_tool = RAGTool(knowledge_base_path="./knowledge_base")
tool_registry.register_tool(rag_tool)

# 为Agent配置工具
agent.tool_registry = tool_registry
print(agent.llm.api_key, agent.llm.base_url, agent.llm.model)
# 开始对话
response = agent.run("你好！请记住我叫张三，我是一名Python开发者")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 11
#       9 os.environ["LLM_MODEL_ID"] =  os.getenv("LLM_MODEL_ID")
#      10 # 创建LLM实例
# ---> 11 llm = HelloAgentsLLM(provider='deepseek', model=os.getenv("LLM_MODEL_ID"), api_key=os.getenv("LLM_API_KEY"), base_url=os.getenv("LLM_BASE_URL"))
#      13 # 创建Agent
#      14 agent = SimpleAgent(
#      15     name="智能助手",
#      16     llm=llm,
#      17     system_prompt="你是一个有记忆和知识检索能力的AI助手"
#      18 )
#
# File ~/Machine Learning/llm/agent/hello-agents/.venv/lib/python3.13/site-packages/hello_agents/core/llm.py:55, in HelloAgentsLLM.__init__(self, model, api_key, base_url, provider, temperature, max_tokens, timeout, **kwargs)
#      53 self.temperature = temperature
#      54 self.max_tokens = max_tokens
# ---> 55 self.timeout = timeout or int(os.getenv("LLM_TIMEOUT", "60"))
#      56 self.kwargs = kwargs
#      58 # 自动检测provider或使用指定的provider
#
# ValueError: invalid literal for int() with base 10: '60s'

# %%
print(os.getenv("DEEPSEEK_API_KEY"))
# Out:
# sk-8df3323590de423a86f433816ee4b30b

# %%
from neo4j import Driver, GraphDatabase
NEO4J_URI="bolt://localhost:7687"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="your_password"
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
driver.session().run("CREATE (n:Person {name:'Alice', age:30})")
